# %%
from strategy import DualReallocationStrategy
import dffc
from dffc import ReallocationBackTest as RBT
import json
import pandas as pd
import numpy as np

pd.set_option('future.no_silent_downcasting', True)

# %% [markdown]
# ## Download & Update Data

# %%
codes = ['007467', '004253']
names=['HL', 'GD']
start_date = '2019-07-01'
end_date = '2025-07-01'

try:
    fund_data = dffc.FundData.load('hlvsgd_all.pkl')
except FileNotFoundError:
    fund_data = dffc.FundData.download(
        codes,
        names=names,
        # start=start_date,
        end=end_date
    )

    fund_data.save('hlvsgd_all.pkl')

fund_data = fund_data.update()
price_data_org = fund_data.get('unit_value') # .dropna()

# %%
fund_data.data['007467']
# Out:
#                            unit_value  cumulative_value  daily_growth_rate  \
# date
# 2017-05-02 00:00:00+08:00         NaN               NaN                NaN
# 2017-05-03 00:00:00+08:00         NaN               NaN                NaN
# 2017-05-04 00:00:00+08:00         NaN               NaN                NaN
# 2017-05-05 00:00:00+08:00         NaN               NaN                NaN
# 2017-05-08 00:00:00+08:00         NaN               NaN                NaN
# ...                               ...               ...                ...
# 2025-11-27 00:00:00+08:00      1.6679            1.9579             0.0019
# 2025-11-28 00:00:00+08:00      1.6653            1.9553            -0.0016
# 2025-12-01 00:00:00+08:00      1.6760            1.9660             0.0064
# 2025-12-02 00:00:00+08:00      1.6747            1.9647            -0.0008
# 2025-12-03 00:00:00+08:00      1.6669            1.9569            -0.0047
#
#                           purchase_state redemption_state bonus_distribution
# date
# 2017-05-02 00:00:00+08:00            NaN              NaN                NaN
# 2017-05-03 00:00:00+08:00            NaN              NaN                NaN
# 2017-05-04 00:00:00+08:00            NaN              NaN                NaN
# 2017-05-05 00:00:00+08:00            NaN              NaN                NaN
# 2017-05-08 00:00:00+08:00            NaN              NaN                NaN
# ...                                  ...              ...                ...
# 2025-11-27 00:00:00+08:00           开放申购             开放赎回
# 2025-11-28 00:00:00+08:00           开放申购             开放赎回
# 2025-12-01 00:00:00+08:00           开放申购             开放赎回
# 2025-12-02 00:00:00+08:00         限制大额申购             开放赎回
# 2025-12-03 00:00:00+08:00         限制大额申购             开放赎回
#
# [2096 rows x 6 columns]

# %%
estimate_p = dffc.FundEstimateProvider()

price_data = dffc.append_estimates_to_prices(
    price_data_org,
    codes,
    estimate_p,
    target_timezone=None,
)
# Out:
# Estimate data fetched for 007467 on 2025-12-03 15:00:00+08:00
# Estimate data fetched for 004253 on 2025-12-03 22:28:00+08:00
# No new estimate rows to append.

# %%
price_data
# Out:
# symbol                     007467  004253
# date
# 2017-05-02 00:00:00+08:00     NaN  1.0725
# 2017-05-03 00:00:00+08:00     NaN  1.0705
# 2017-05-04 00:00:00+08:00     NaN  1.0555
# 2017-05-05 00:00:00+08:00     NaN  1.0543
# 2017-05-08 00:00:00+08:00     NaN  1.0529
# ...                           ...     ...
# 2025-11-27 00:00:00+08:00  1.6679  3.3387
# 2025-11-28 00:00:00+08:00  1.6653  3.3538
# 2025-12-01 00:00:00+08:00  1.6760  3.3898
# 2025-12-02 00:00:00+08:00  1.6747  3.3776
# 2025-12-03 00:00:00+08:00  1.6669  3.3610
#
# [2096 rows x 2 columns]

# %% [markdown]
# ## Load HW Parameter

# %%
with open('../hw_opt_results/demo_hw.json', 'r') as f:
    opt_res = json.load(f)

# %% [markdown]
# ## Backtest Strategy

# %%
single_strategy = DualReallocationStrategy(
    prices = price_data,
    threshold=0.6,
    adjust_factor=0.2,
    default_weights = 0.5,
    up_weights = 0.2,
    down_weights= 0.8,
    tolerance=0.01,
    hw_params_list = opt_res
)

# %%
single_bt = RBT(
    strategy=single_strategy
)

single_bt.run(    
    start_date="2022-07-01",
    end_date=None,
    initial_cash=100_000,
    fees=0.0,
    trade_delay=0
)
# Out:
# 2022-07-01 None
# 2022-07-01 00:00:00+08:00 None
# 100%|██████████| 1/1 [00:00<00:00,  1.26it/s]

# %%
single_bt.stats()
# Out:
# Start                           2022-07-01 00:00:00+08:00
# End                             2025-12-03 00:00:00+08:00
# Period                                  835 days 00:00:00
# Start Value                                      100000.0
# End Value                                   193244.505557
# Total Return [%]                                93.244506
# Benchmark Return [%]                            74.859158
# Max Gross Exposure [%]                              100.0
# Total Fees Paid                                       0.0
# Max Drawdown [%]                                 7.351418
# Max Drawdown Duration                    83 days 00:00:00
# Total Trades                                          621
# Total Closed Trades                                   619
# Total Open Trades                                       2
# Open Trade PnL                                6232.745684
# Win Rate [%]                                    86.914378
# Best Trade [%]                                  24.028208
# Worst Trade [%]                                 -5.177767
# Avg Winning Trade [%]                            4.231669
# Avg Losing Trade [%]                            -2.125073
# Avg Winning Trade Duration    434 days 16:46:23.643122680
# Avg Losing Trade Duration     374 days 17:28:53.333333336
# Profit Factor                                    14.66763
# Expectancy                                     140.568271
# Sharpe Ratio                                      1.90441
# Calmar Ratio                                     2.992096
# Omega Ratio                                      1.409672
# Sortino Ratio                                    2.853545
# dtype: object

# %%
single_bt.plot()

# %%
single_strategy.hw_signals
# Out:
#                              007467    004253
# date
# 2022-07-01 00:00:00+08:00  0.287749 -0.806656
# 2022-07-04 00:00:00+08:00  0.116809 -0.629160
# 2022-07-05 00:00:00+08:00  0.198864 -0.645570
# 2022-07-06 00:00:00+08:00 -0.261364 -0.908228
# 2022-07-07 00:00:00+08:00 -0.280453 -0.952607
# ...                             ...       ...
# 2025-11-26 00:00:00+08:00 -0.623529 -0.498565
# 2025-11-27 00:00:00+08:00 -0.579634 -0.076482
# 2025-11-28 00:00:00+08:00 -0.650131  0.195029
# 2025-12-01 00:00:00+08:00 -0.452412  0.787966
# 2025-12-02 00:00:00+08:00 -0.486310  0.562560
#
# [834 rows x 2 columns]

# %%
single_bt.plot(column = single_bt.pf.close.columns[1])
# Out:
# FigureWidget({
#     'data': [{'legendgroup': '0',
#               'line': {'color': '#1f77b4'},
#               'name': 'Close',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': 'cbae106a-e35b-496a-b8c8-47adac9e24a3',
#               'x': array([Timestamp('2022-07-01 00:00:00+0800', tz='UTC+08:00'),
#                           Timestamp('2022-07-04 00:00:00+0800', tz='UTC+08:00'),
#                           Timestamp('2022-07-05 00:00:00+0800', tz='UTC+08:00'), ...,
#                           Timestamp('2025-11-28 00:00:00+0800', tz='UTC+08:00'),
#                           Timestamp('2025-12-01 00:00:00+0800', tz='UTC+08:00'),
#                           Timestamp('2025-12-02 00:00:00+0800', tz='UTC+08:00')],
#                          shape=(834,), dtype=object),
#               'xaxis': 'x',
#               'y': {'bdata': ('ppvEILBy9z/eAgmKH2P3P9v5fmq8dP' ... 'XgnBGl+j83iUFg5dD6P5huEoPAyvo/'),
#                     'dtype': 'f8'},
#               'yaxis': 'y'},
#              {'customdata': {'bdata': ('AAAAAAAA8D97FK5HwajgQAAAAAAAAA' ... 'AAAABUk0AK16NwHf3AQAAAAAAAAAAA'),
#                              'dtype': 'f8',
#                              'shape': '318, 3'},
#               'hovertemplate': ('Order Id: %{customdata[0]}<br>' ... '<br>Fees: %{customdata[2]:.6f}'),
#               'legendgroup': '1',
#               'marker': {'color': '#37B13F',
#                          'line': {'color': 'rgb(38,123,44)', 'width': 1},
#                          'size': 8,
#                          'symbol': 'triangle-up'},
#               'mode': 'markers',
#               'name': 'Buy',
#               'type': 'scatter',
#               'uid
dtype': 'f8'},
#                          'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'Open',
#               'type': 'scatter',
#               'uid': '01189963-f1ae-4cf9-92ad-af224b1e02de',
#               'x': array([Timestamp('2025-12-02 00:00:00+0800', tz='UTC+08:00')], dtype=object),
#               'xaxis': 'x2',
#               'y': {'bdata': 'ACosIgURcT8=', 'dtype': 'f8'},
#               'yaxis': 'y2'},
#              {'legendgroup': '6',
#               'line': {'color': '#7f7f7f'},
#               'name': 'Benchmark',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '5ac40454-decd-46b1-94bf-ed3810bee757',
#               'x': array([Timestamp('2022-07-01 00:00:00+0800', tz='UTC+08:00'),
#                           Timestamp('2022-07-04 00:00:00+0800', tz='UTC+08:00'),
#                           Timestamp('2022-07-05 00:00:00+0800', tz='UTC+08:00'), ...,
#                           Timestamp('2025-11-28 00:00:00+0800', tz='UTC+08:00'),
#                           Timestamp('2025-12-01 00:00:00+0800', tz='UTC+08:00'),
#                           Timestamp('2025-12-02 00:00:00+0800', tz='UTC+08:00')],
#                          shape=(834,), dtype=object),
#               'xaxis': 'x3',
#               'y': {'bdata': ('AAAAAAAA8D8EpO0kwurvP6Fd8MBlAf' ... '2YXW4u8j+C+klLVkzyP57heAglSPI/'),
#                     'dtype': 'f8'},
#               'yaxis': 'y3'},
#              {'hoverinfo': 'skip',
#               'legendgroup': '7',
#               'line': {'color': 'rgba(0, 0, 0, 0)', 'width': 0},
#               'opacity': 0,
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': 'e4516437-c8a1-4c21-b0ab-b7bfcc39b935',
#               'x': array([Timestamp('2022-07-01 00:00:00+0800', tz='UTC+08:00'),
#                           Timestamp('2022-07-04 00:00:00+0800', tz='UTC+08:00'),
#                           Timestamp('2022-07-05 00:00:00+0800', tz='UTC+08:00'), ...,
#                           Timestamp('2025-11-28 00:00:00+0800', tz='UTC+08:00'),
#                           Timestamp('2025-12-01 00:00:00+0800', tz='UTC+08:00'),
#                           Timestamp('2025-12-02 00:00:00+0800', tz='UTC+08:00')],
#                          shape=(834,), dtype=object),
#               'xaxis': 'x3',
#               'y': {'bdata': ('AQEBAQEBAQEBAQEBAQEBAQEBAQEBAQ' ... 'EBAQEBAQEBAQEBAQEBAQEBAQEBAQEB'),
#                     'dtype': 'i1'},
#               'yaxis': 'y3'},
#              {'connectgaps': False,
#               'fill': 'tonexty',
#               'fillcolor': 'rgba(0, 128, 0, 0.3)',
#               'hoverinfo': 'skip',
#               'legendgroup': '7',
#               'line': {'color': 'rgba(0, 0, 0, 0)', 'width': 0},
#               'opacity': 0,
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '1375a833-d4f0-4315-9442-7cf581713880',
#               'x': array([Timestamp('2022-07-01 00:00:00+0800', tz='UTC+08:00'),
#                           Timestamp('2022-07-04 00:00:00+0800', tz='UTC+08:00'),
#                           Timestamp('2022-07-05 00:00:00+0800', tz='UTC+08:00'), ...,
#                           Timestamp('2025-11-28 00:00:00+0800', tz='UTC+08:00'),
#                           Timestamp('2025-12-01 00:00:00+0800', tz='UTC+08:00'),
#                           Timestamp('2025-12-02 00:00:00+0800', tz='UTC+08:00')],
#                          shape=(834,), dtype=object),
#               'xaxis': 'x3',
#               'y': {'bdata': ('AAAAAAAA8D8AAAAAAADwPwAAAAAAAP' ... 'inoCkV9D8COSfOvyX0P7TrLva9IvQ/'),
#                     'dtype': 'f8'},
#               'yaxis': 'y3'},
#              {'hoverinfo': 'skip',
#               'legendgroup': '7',
#               'line': {'color': 'rgba(0, 0, 0, 0)', 'width': 0},
#               'opacity': 0,
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': 'd8dabaa9-b7d4-440c-a82f-25d4973a2a2c',
#               'x': array([Timestamp('2022-07-01 00:00:00+0800', tz='UTC+08:00'),
#                           Timestamp('2022-07-04 00:00:00+0800', tz='UTC+08:00'),
#                           Timestamp('2022-07-05 00:00:00+0800', tz='UTC+08:00'), ...,
#                           Timestamp('2025-11-28 00:00:00+0800', tz='UTC+08:00'),
#                           Timestamp('2025-12-01 00:00:00+0800', tz='UTC+08:00'),
#                           Timestamp('2025-12-02 00:00:00+0800', tz='UTC+08:00')],
#                          shape=(834,), dtype=object),
#               'xaxis': 'x3',
#               'y': {'bdata': ('AQEBAQEBAQEBAQEBAQEBAQEBAQEBAQ' ... 'EBAQEBAQEBAQEBAQEBAQEBAQEBAQEB'),
#                     'dtype': 'i1'},
#               'yaxis': 'y3'},
#              {'connectgaps': False,
#               'fill': 'tonexty',
#               'fillcolor': 'rgba(255, 0, 0, 0.3)',
#               'hoverinfo': 'skip',
#               'legendgroup': '7',
#               'line': {'color': 'rgba(0, 0, 0, 0)', 'width': 0},
#               'opacity': 0,
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': 'c687c2b4-a745-4bd0-8d5e-5e8b28e071ad',
#               'x': array([Timestamp('2022-07-01 00:00:00+0800', tz='UTC+08:00'),
#                           Timestamp('2022-07-04 00:00:00+0800', tz='UTC+08:00'),
#                           Timestamp('2022-07-05 00:00:00+0800', tz='UTC+08:00'), ...,
#                           Timestamp('2025-11-28 00:00:00+0800', tz='UTC+08:00'),
#                           Timestamp('2025-12-01 00:00:00+0800', tz='UTC+08:00'),
#                           Timestamp('2025-12-02 00:00:00+0800', tz='UTC+08:00')],
#                          shape=(834,), dtype=object),
#               'xaxis': 'x3',
#               'y': {'bdata': ('AAAAAAAA8D+K8KISYfXvP2wThdb+/+' ... 'AAAAAA8D8AAAAAAADwPwAAAAAAAPA/'),
#                     'dtype': 'f8'},
#               'yaxis': 'y3'},
#              {'legendgroup': '8',
#               'line': {'color': '#9467bd'},
#               'name': 'Value',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': 'befa6670-3bc5-496b-a2f1-18b673fd73e3',
#               'x': array([Timestamp('2022-07-01 00:00:00+0800', tz='UTC+08:00'),
#                           Timestamp('2022-07-04 00:00:00+0800', tz='UTC+08:00'),
#                           Timestamp('2022-07-05 00:00:00+0800', tz='UTC+08:00'), ...,
#                           Timestamp('2025-11-28 00:00:00+0800', tz='UTC+08:00'),
#                           Timestamp('2025-12-01 00:00:00+0800', tz='UTC+08:00'),
#                           Timestamp('2025-12-02 00:00:00+0800', tz='UTC+08:00')],
#                          shape=(834,), dtype=object),
#               'xaxis': 'x3',
#               'y': {'bdata': ('AAAAAAAA8D+K8KISYfXvP2wThdb+/+' ... 'inoCkV9D8COSfOvyX0P7TrLva9IvQ/'),
#                     'dtype': 'f8'},
#               'yaxis': 'y3'},
#              {'hoverinfo': 'skip',
#               'legendgroup': '7',
#               'line': {'color': 'rgba(0, 0, 0, 0)', 'width': 0},
#               'opacity': 0.0,
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': 'b8cb1c3b-4a86-423d-a3cb-a017a3f7b47e',
#               'x': array([Timestamp('2022-07-01 00:00:00+0800', tz='UTC+08:00'),
#                           Timestamp('2022-07-04 00:00:00+0800', tz='UTC+08:00'),
#                           Timestamp('2022-07-05 00:00:00+0800', tz='UTC+08:00'), ...,
#                           Timestamp('2025-11-28 00:00:00+0800', tz='UTC+08:00'),
#                           Timestamp('2025-12-01 00:00:00+0800', tz='UTC+08:00'),
#                           Timestamp('2025-12-02 00:00:00+0800', tz='UTC+08:00')],
#                          shape=(834,), dtype=object),
#               'xaxis': 'x3',
#               'y': {'bdata': ('AQEBAQEBAQEBAQEBAQEBAQEBAQEBAQ' ... 'EBAQEBAQEBAQEBAQEBAQEBAQEBAQEB'),
#                     'dtype': 'i1'},
#               'yaxis': 'y3'}],
#     'layout': {'annotations': [{'font': {'size': 16},
#                                 'showarrow': False,
#                                 'text': 'Orders',
#                                 'x': 0.5,
#                                 'xanchor': 'center',
#                                 'xref': 'paper',
#                                 'y': 1.0,
#                                 'yanchor': 'bottom',
#                                 'yref': 'paper'},
#                                {'font': {'size': 16},
#                                 'showarrow': False,
#                                 'text': 'Trade PnL',
#                                 'x': 0.5,
#                                 'xanchor': 'center',
#                                 'xref': 'paper',
#                                 'y': 0.6527777777777777,
#                                 'yanchor': 'bottom',
#                                 'yref': 'paper'},
#                                {'font': {'size': 16},
#                                 'showarrow': False,
#                                 'text': 'Cumulative Returns',
#                                 'x': 0.5,
#                                 'xanchor': 'center',
#                                 'xref': 'paper',
#                                 'y': 0.3055555555555555,
#                                 'yanchor': 'bottom',
#                                 'yref': 'paper'}],
#                'height': 960,
#                'legend': {'orientation': 'h',
#                           'traceorder': 'normal',
#                           'x': 1,
#                           'xanchor': 'right',
#                           'y': 1.0416666666666667,
#                           'yanchor': 'bottom'},
#                'margin': {'b': 30, 'l': 30, 'r': 30, 't': 30},
#                'shapes': [{'line': {'color': 'gray', 'dash': 'dash'},
#                            'type': 'line',
#                            'x0': 0.0,
#                            'x1': 1.0,
#                            'xref': 'paper',
#                            'y0': 0,
#                            'y1': 0,
#                            'yref': 'y2'},
#                           {'line': {'color': 'gray', 'dash': 'dash'},
#                            'type': 'line',
#                            'x0': 0.0,
#                            'x1': 1.0,
#                            'xref': 'paper',
#                            'y0': 1,
#                            'y1': 1,
#                            'yref': 'y3'}],
#                'showlegend': True,
#                'template': '...',
#                'width': 750,
#                'xaxis': {'anchor': 'y', 'domain': [0.0, 1.0], 'matches': 'x3', 'showticklabels': False},
#                'xaxis2': {'anchor': 'y2', 'domain': [0.0, 1.0], 'matches': 'x3', 'showticklabels': False},
#                'xaxis3': {'anchor': 'y3', 'domain': [0.0, 1.0], 'title': {'text': 'Index'}},
#                'yaxis': {'anchor': 'x', 'domain': [0.6944444444444444, 1.0], 'title': {'text': 'Price'}},
#                'yaxis2': {'anchor': 'x2',
#                           'domain': [0.3472222222222222, 0.6527777777777777],
#                           'tickformat': '.2%',
#                           'title': {'text': 'Trade PnL'}},
#                'yaxis3': {'anchor': 'x3', 'domain': [0.0, 0.3055555555555555], 'title': {'text': 'Cumulative returns'}}}
# })

# %% [markdown]
# ## Hyperparameter Optimization

# %%
strategy = DualReallocationStrategy(
    prices = price_data,
    threshold= np.arange(0.3, 2.0, 0.01),
    adjust_factor= np.arange(0.1, 1.1, 0.1),
    default_weights = 0.5,
    up_weights = np.arange(0.1, 0.5, 0.1),
    down_weights= np.arange(0.6, 1.0, 0.1),
    tolerance=0.01,
    hw_params_list = opt_res
)

# %%
bt = RBT(
    strategy=strategy,
    start_date="2022-07-01",
    end_date="2025-07-01",
    initial_cash=100_000,
    fees=0.,
    trade_delay=0
)

bt.run()
# Out:
# 100%|██████████| 27200/27200 [11:50<00:00, 38.27it/s]

# %%
bt.stats() # selected=1
# Out:
#                                                                                        benchmark_return  \
# param_group threshold adjust_factor default_weights up_weights down_weights tolerance
# 0           0.30      0.1           0.5             0.1        0.6          0.01               0.540756
# 1           0.30      0.1           0.5             0.1        0.7          0.01               0.540756
# 2           0.30      0.1           0.5             0.1        0.8          0.01               0.540756
# 3           0.30      0.1           0.5             0.1        0.9          0.01               0.540756
# 4           0.30      0.1           0.5             0.2        0.6          0.01               0.540756
# ...                                                                                                 ...
# 27195       1.99      1.0           0.5             0.3        0.9          0.01               0.540756
# 27196       1.99      1.0           0.5             0.4        0.6          0.01               0.540756
# 27197       1.99      1.0           0.5             0.4        0.7          0.01               0.540756
# 27198       1.99      1.0           0.5             0.4        0.8          0.01               0.540756
# 27199       1.99      1.0           0.5             0.4        0.9          0.01               0.540756
#
#                                                                                        total_return  \
# param_group threshold adjust_factor default_weights up_weights down_weights tolerance
# 0           0.30      0.1           0.5             0.1        0.6          0.01           0.761648
# 1           0.30      0.1           0.5             0.1        0.7          0.01           0.744032
# 2           0.30      0.1           0.5             0.1        0.8          0.01           0.725808
# 3           0.30      0.1           0.5             0.1        0.9          0.01           0.707083
# 4           0.30      0.1           0.5             0.2        0.6          0.01           0.690909
# ...                                                                                             ...
# 27195       1.99      1.0           0.5             0.3        0.9          0.01           0.540756
# 27196       1.99      1.0           0.5             0.4        0.6          0.01           0.540756
# 27197       1.99      1.0           0.5             0.4        0.7          0.01           0.540756
# 27198       1.99      1.0           0.5             0.4        0.8          0.01           0.540756
# 27199       1.99      1.0           0.5             0.4        0.9          0.01           0.540756
#
#                                                                                        sharpe_ratio  \
# param_group threshold adjust_factor default_weights up_weights down_weights tolerance
# 0           0.30      0.1           0.5             0.1        0.6          0.01           2.018393
# 1           0.30      0.1           0.5             0.1        0.7          0.01           1.967199
# 2           0.30      0.1           0.5             0.1        0.8          0.01           1.891587
# 3           0.30      0.1           0.5             0.1        0.9          0.01           1.797507
# 4           0.30      0.1           0.5             0.2        0.6          0.01           1.876911
# ...                                                                                             ...
# 27195       1.99      1.0           0.5             0.3        0.9          0.01           1.508663
# 27196       1.99      1.0           0.5             0.4        0.6          0.01           1.508663
# 27197       1.99      1.0           0.5             0.4        0.7          0.01           1.508663
# 27198       1.99      1.0           0.5             0.4        0.8          0.01           1.508663
# 27199       1.99      1.0           0.5             0.4        0.9          0.01           1.508663
#
#                                                                                        max_drawdown
# param_group threshold adjust_factor default_weights up_weights down_weights tolerance
# 0           0.30      0.1           0.5             0.1        0.6          0.01          -0.052947
# 1           0.30      0.1           0.5             0.1        0.7          0.01          -0.061328
# 2           0.30      0.1           0.5             0.1        0.8          0.01          -0.069653
# 3           0.30      0.1           0.5             0.1        0.9          0.01          -0.077921
# 4           0.30      0.1           0.5             0.2        0.6          0.01          -0.057642
# ...                                                                                             ...
# 27195       1.99      1.0           0.5             0.3        0.9          0.01          -0.065664
# 27196       1.99      1.0           0.5             0.4        0.6          0.01          -0.065664
# 27197       1.99      1.0           0.5             0.4        0.7          0.01          -0.065664
# 27198       1.99      1.0           0.5             0.4        0.8          0.01          -0.065664
# 27199       1.99      1.0           0.5             0.4        0.9          0.01          -0.065664
#
# [27200 rows x 4 columns]

# %%
bt.plot(index_levels=['threshold', 'adjust_factor'], column_levels=['up_weights', 'down_weights'])

# %%
# Map top indices to their parameter sets without using an unhashable Index as a dict key
best_params = bt.get_best_param(metric='total_return', top_n=5)
best_params
# Out:
#    param_group  threshold  adjust_factor  default_weights  up_weights  \
# 0         7411       0.76            0.4              0.5         0.1
# 1         7571       0.77            0.4              0.5         0.1
# 2         7395       0.76            0.3              0.5         0.1
# 3         7555       0.77            0.3              0.5         0.1
# 4         7427       0.76            0.5              0.5         0.1
#
#    down_weights  tolerance  total_return
# 0           0.9       0.01      1.135884
# 1           0.9       0.01      1.135884
# 2           0.9       0.01      1.129134
# 3           0.9       0.01      1.129134
# 4           0.9       0.01      1.127818

# %%
best_params= bt.get_weighted_best_params(
    metric_weight = {
        'total_return': 0.45,
        'sharpe_ratio': 0.45,
        'max_drawdown': 0.1
    },
    top_n=10
)

# %%
best_params
# Out:
#    param_group  threshold  adjust_factor  default_weights  up_weights  \
# 0         7394       0.76            0.3              0.5         0.1
# 1         7554       0.77            0.3              0.5         0.1
# 2         7553       0.77            0.3              0.5         0.1
# 3         7393       0.76            0.3              0.5         0.1
# 4         7570       0.77            0.4              0.5         0.1
# 5         7410       0.76            0.4              0.5         0.1
# 6         7555       0.77            0.3              0.5         0.1
# 7         7395       0.76            0.3              0.5         0.1
# 8         7569       0.77            0.4              0.5         0.1
# 9         7409       0.76            0.4              0.5         0.1
#
#    down_weights  tolerance  weighted_score  total_return  sharpe_ratio  \
# 0           0.8       0.01        0.943068      1.090581      2.378682
# 1           0.8       0.01        0.943068      1.090581      2.378682
# 2           0.7       0.01        0.942933      1.054875      2.410353
# 3           0.7       0.01        0.942933      1.054875      2.410353
# 4           0.8       0.01        0.940524      1.098267      2.360741
# 5           0.8       0.01        0.940524      1.098267      2.360741
# 6           0.9       0.01        0.938446      1.129134      2.322774
# 7           0.9       0.01        0.938446      1.129134      2.322774
# 8           0.7       0.01        0.935924      1.055579      2.387905
# 9           0.7       0.01        0.935924      1.055579      2.387905
#
#    max_drawdown
# 0     -0.070904
# 1     -0.070904
# 2     -0.062222
# 3     -0.062222
# 4     -0.072587
# 5     -0.072587
# 6     -0.079690
# 7     -0.079690
# 8     -0.063761
# 9     -0.063761

# %% [markdown]
# ## Best Param Strategy

# %%
best_strategy = DualReallocationStrategy(
    prices = price_data,
    threshold = best_params['threshold'][0],
    adjust_factor = best_params['adjust_factor'][0],
    default_weights = 0.,
    up_weights = best_params['up_weights'][0],
    down_weights = best_params['down_weights'][0],
    tolerance=0.01,
    hw_params_list = opt_res
)

# %%
best_bt = RBT(
    strategy=best_strategy,
    start_date="2022-07-01",
    # end_date="2025-07-02",
    initial_cash=20_000,
    fees=0.0,
    trade_delay=0
)

best_bt.run()
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# 100%|██████████| 1/1 [00:00<00:00,  6.54it/s]

# %%
best_strategy.hw_signals
# Out:
#                              007467    004253
# date
# 2024-07-17 00:00:00+08:00 -0.556667  0.946667
# 2024-07-18 00:00:00+08:00 -0.384359  0.920133
# 2024-07-19 00:00:00+08:00 -0.607321 -0.670549
# 2024-07-22 00:00:00+08:00 -0.813953 -0.239203
# 2024-07-23 00:00:00+08:00 -0.850498 -0.677741
# ...                             ...       ...
# 2025-10-23 00:00:00+08:00  0.816733 -0.399734
# 2025-10-24 00:00:00+08:00  0.493369 -0.864721
# 2025-10-27 00:00:00+08:00  0.506631 -0.949602
# 2025-10-28 00:00:00+08:00  0.486093 -1.000000
# 2025-10-29 00:00:00+08:00  0.115232 -0.994702
#
# [311 rows x 2 columns]

# %%
best_bt.pf.orders.records_readable
# Out:
#     Order Id                                       Column  \
# 0          0  (0, 0.92, 0.8, 0.5, 0.1, 0.6, 0.01, 004253)
# 1          1  (0, 0.92, 0.8, 0.5, 0.1, 0.6, 0.01, 007467)
# 2          2  (0, 0.92, 0.8, 0.5, 0.1, 0.6, 0.01, 004253)
# 3          3  (0, 0.92, 0.8, 0.5, 0.1, 0.6, 0.01, 007467)
# 4          4  (0, 0.92, 0.8, 0.5, 0.1, 0.6, 0.01, 004253)
# 5          5  (0, 0.92, 0.8, 0.5, 0.1, 0.6, 0.01, 007467)
# 6          6  (0, 0.92, 0.8, 0.5, 0.1, 0.6, 0.01, 007467)
# 7          7  (0, 0.92, 0.8, 0.5, 0.1, 0.6, 0.01, 004253)
# 8          8  (0, 0.92, 0.8, 0.5, 0.1, 0.6, 0.01, 007467)
# 9          9  (0, 0.92, 0.8, 0.5, 0.1, 0.6, 0.01, 004253)
# 10        10  (0, 0.92, 0.8, 0.5, 0.1, 0.6, 0.01, 007467)
# 11        11  (0, 0.92, 0.8, 0.5, 0.1, 0.6, 0.01, 004253)
# 12        12  (0, 0.92, 0.8, 0.5, 0.1, 0.6, 0.01, 004253)
# 13        13  (0, 0.92, 0.8, 0.5, 0.1, 0.6, 0.01, 007467)
# 14        14  (0, 0.92, 0.8, 0.5, 0.1, 0.6, 0.01, 004253)
#
# Avg Losing Trade [%]                            -1.662644
# Avg Winning Trade Duration    436 days 23:36:11.900826448
# Avg Losing Trade Duration     396 days 13:27:16.363636364
# Profit Factor                                   14.845681
# Expectancy                                      55.435709
# Sharpe Ratio                                     2.353979
# Calmar Ratio                                     4.047467
# Omega Ratio                                      1.534999
# Sortino Ratio                                    3.566214
# dtype: object

# %%
best_bt.plot()

# %%
best_bt.pf.orders.records_readable
# Out:
#      Order Id                                       Column  \
# 0           0  (0, 0.83, 0.2, 0.0, 0.1, 0.6, 0.01, 004253)
# 1           1  (0, 0.83, 0.2, 0.0, 0.1, 0.6, 0.01, 004253)
# 2           2  (0, 0.83, 0.2, 0.0, 0.1, 0.6, 0.01, 007467)
# 3           3  (0, 0.83, 0.2, 0.0, 0.1, 0.6, 0.01, 004253)
# 4           4  (0, 0.83, 0.2, 0.0, 0.1, 0.6, 0.01, 007467)
# ..        ...                                          ...
# 98         98  (0, 0.83, 0.2, 0.0, 0.1, 0.6, 0.01, 004253)
# 99         99  (0, 0.83, 0.2, 0.0, 0.1, 0.6, 0.01, 007467)
# 100       100  (0, 0.83, 0.2, 0.0, 0.1, 0.6, 0.01, 004253)
# 101       101  (0, 0.83, 0.2, 0.0, 0.1, 0.6, 0.01, 007467)
# 102       102  (0, 0.83, 0.2, 0.0, 0.1, 0.6, 0.01, 004253)
#
#                     Timestamp     Size   Price  Fees  Side
# 0   2025-05-28 00:00:00+08:00  7295.80  2.7413   0.0   Buy
# 1   2025-05-29 00:00:00+08:00   145.90  2.7174   0.0  Sell
# 2   2025-05-29 00:00:00+08:00   242.51  1.6349   0.0   Buy
# 3   2025-05-30 00:00:00+08:00   117.36  2.7379   0.0  Sell
# 4   2025-05-30 00:00:00+08:00   195.94  1.6399   0.0   Buy
# ..                        ...      ...     ...   ...   ...
# 98  2025-10-27 00:00:00+08:00   435.49  3.2970   0.0   Buy
# 99  2025-10-28 00:00:00+08:00   766.79  1.6626   0.0  Sell
# 100 2025-10-28 00:00:00+08:00   401.36  3.1764   0.0   Buy
# 101 2025-10-29 00:00:00+08:00   488.22  1.6492   0.0  Sell
# 102 2025-10-29 00:00:00+08:00   251.47  3.2018   0.0   Buy
#
# [103 rows x 7 columns]

# %%
delta_hdp = - best_strategy.hw_signals.iloc[:, 0] + best_strategy.hw_signals.iloc[:, 1]

# %%
best_strategy.hw_signals
# Out:
#                              007467    004253
# date
# 2025-05-28 00:00:00+08:00  0.335227 -0.446023
# 2025-05-29 00:00:00+08:00  0.232955 -0.877841
# 2025-05-30 00:00:00+08:00  0.293617 -0.273759
# 2025-06-03 00:00:00+08:00  0.690780  0.571631
# 2025-06-04 00:00:00+08:00  0.742210  0.399433
# ...                             ...       ...
# 2025-10-23 00:00:00+08:00  0.819389 -0.776892
# 2025-10-24 00:00:00+08:00  0.498674 -0.928382
# 2025-10-27 00:00:00+08:00  0.509284 -0.954907
# 2025-10-28 00:00:00+08:00  0.480795 -1.000000
# 2025-10-29 00:00:00+08:00 -0.027815 -0.994702
#
# [104 rows x 2 columns]

# %%
delta_hdp
# Out:
# date
# 2025-05-28 00:00:00+08:00   -0.781250
# 2025-05-29 00:00:00+08:00   -1.110795
# 2025-05-30 00:00:00+08:00   -0.567376
# 2025-06-03 00:00:00+08:00   -0.119149
# 2025-06-04 00:00:00+08:00   -0.342776
#                                ...
# 2025-10-23 00:00:00+08:00   -1.596282
# 2025-10-24 00:00:00+08:00   -1.427056
# 2025-10-27 00:00:00+08:00   -1.464191
# 2025-10-28 00:00:00+08:00   -1.480795
# 2025-10-29 00:00:00+08:00   -0.966887
# Length: 104, dtype: float64
