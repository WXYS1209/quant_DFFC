# %%
from strategy import DualReallocationStrategy
import dffc
from dffc import HWOptimizer
from dffc import ReallocationBackTest as RBT
import json
import pandas as pd
import numpy as np

pd.set_option('future.no_silent_downcasting', True)

# %% [markdown]
# ## Download & Update Data

# %%
codes = ['007467', '004253']
names=['HL', 'GD']
start_date = '2019-07-01'
end_date = '2025-07-01'

try:
    fund_data = dffc.FundData.load('hlvsgd_all.pkl')
except FileNotFoundError:
    fund_data = dffc.FundData.download(
        codes,
        names=names,
        # start=start_date,
        end=end_date
    )

    fund_data.save('hlvsgd_all.pkl')

fund_data = fund_data.update()
price_data_org = fund_data.get('unit_value') # .dropna()

# %%
estimate_p = dffc.FundEstimateProvider()

price_data = dffc.append_estimates_to_prices(
    price_data_org,
    codes,
    estimate_p,
    target_timezone=None,
)
# Out:
# Estimate data fetched for 007467 on 2025-11-28 11:30:00+08:00
# Estimate data fetched for 004253 on 2025-11-28 12:38:00+08:00
# Added estimate rows for dates: 2025-11-28.

# %%
price_data
# Out:
#                            007467  004253
# date
# 2017-05-02 00:00:00+08:00     NaN  1.0725
# 2017-05-03 00:00:00+08:00     NaN  1.0705
# 2017-05-04 00:00:00+08:00     NaN  1.0555
# 2017-05-05 00:00:00+08:00     NaN  1.0543
# 2017-05-08 00:00:00+08:00     NaN  1.0529
# ...                           ...     ...
# 2025-11-24 00:00:00+08:00  1.6641  3.2760
# 2025-11-25 00:00:00+08:00  1.6738  3.3305
# 2025-11-26 00:00:00+08:00  1.6647  3.3298
# 2025-11-27 00:00:00+08:00  1.6679  3.3387
# 2025-11-28 00:00:00+08:00  1.6661  3.3522
#
# [2093 rows x 2 columns]

# %% [markdown]
# ## Load HW Parameter

# %%
with open('../hw_opt_results/demo_hw.json', 'r') as f:
    opt_res = json.load(f)

# %% [markdown]
# ## Backtest Strategy

# %%
single_strategy = DualReallocationStrategy(
    prices = price_data,
    threshold=0.6,
    adjust_factor=0.2,
    default_weights = 0.5,
    up_weights = 0.2,
    down_weights= 0.8,
    tolerance=0.01,
    hw_params_list = opt_res
)

# %%
single_bt = RBT(
    strategy=single_strategy,
    start_date="2022-07-01",
    end_date=None,
    initial_cash=100_000,
    fees=0.0,
    trade_delay=0
)

single_bt.run()
# Out:
# 100%|██████████| 1/1 [00:00<00:00,  7.33it/s]

# %%
single_bt.stats()
# Out:
# Start                           2022-07-01 00:00:00+08:00
# End                             2025-11-28 00:00:00+08:00
# Period                                  832 days 00:00:00
# Start Value                                      100000.0
# End Value                                   192790.176477
# Total Return [%]                                92.790176
# Benchmark Return [%]                             74.52294
# Max Gross Exposure [%]                              100.0
# Total Fees Paid                                       0.0
# Max Drawdown [%]                                 7.351418
# Max Drawdown Duration                    83 days 00:00:00
# Total Trades                                          618
# Total Closed Trades                                   616
# Total Open Trades                                       2
# Open Trade PnL                                9296.545733
# Win Rate [%]                                    86.850649
# Best Trade [%]                                  24.028208
# Worst Trade [%]                                 -5.177767
# Avg Winning Trade [%]                            4.208167
# Avg Losing Trade [%]                            -2.125073
# Avg Winning Trade Duration    432 days 11:10:12.336448600
# Avg Losing Trade Duration     374 days 17:28:53.333333336
# Profit Factor                                    14.11501
# Expectancy                                     135.541608
# Sharpe Ratio                                     1.903928
# Calmar Ratio                                     2.992161
# Omega Ratio                                      1.409997
# Sortino Ratio                                    2.850919
# dtype: object

# %%
single_bt.plot()

# %%
single_strategy.hw
# Out:
#                              007467    004253
# date
# 2017-05-02 00:00:00+08:00       NaN  1.068871
# 2017-05-03 00:00:00+08:00       NaN  1.074937
# 2017-05-04 00:00:00+08:00       NaN  1.069308
# 2017-05-05 00:00:00+08:00       NaN  1.068094
# 2017-05-08 00:00:00+08:00       NaN  1.063885
# ...                             ...       ...
# 2025-11-24 00:00:00+08:00  1.684591  3.306071
# 2025-11-25 00:00:00+08:00  1.682748  3.300348
# 2025-11-26 00:00:00+08:00  1.685003  3.293020
# 2025-11-27 00:00:00+08:00  1.685099  3.313956
# 2025-11-28 00:00:00+08:00  1.683164  3.312969
#
# [2093 rows x 2 columns]

# %%
single_bt.plot(column = single_bt.pf.close.columns[1])
# Out:
# FigureWidget({
#     'data': [{'legendgroup': '0',
#               'line': {'color': '#1f77b4'},
#               'name': 'Close',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': 'b5a6f548-f80f-4f5f-ba2b-700665caace3',
#               'x': array([Timestamp('2025-01-02 00:00:00+0800', tz='UTC+08:00'),
#                           Timestamp('2025-01-03 00:00:00+0800', tz='UTC+08:00'),
#                           Timestamp('2025-01-06 00:00:00+0800', tz='UTC+08:00'), ...,
#                           Timestamp('2025-11-26 00:00:00+0800', tz='UTC+08:00'),
#                           Timestamp('2025-11-27 00:00:00+0800', tz='UTC+08:00'),
#                           Timestamp('2025-11-28 00:00:00+0800', tz='UTC+08:00')],
#                          shape=(220,), dtype=object),
#               'xaxis': 'x',
#               'y': {'bdata': ('io7k8h/S+T8eFmpN8475P3UCmggbnv' ... 'p3nKL6P3L5D+m3r/o/f9k9eVio+j8='),
#                     'dtype': 'f8'},
#               'yaxis': 'y'},
#              {'customdata': {'bdata': ('AAAAAAAA8D/NzMzMjDS4QAAAAAAAAA' ... 'AAAAAAP0DsUbgehRd1QAAAAAAAAAAA'),
#                              'dtype': 'f8',
#                              'shape': '10, 3'},
#               'hovertemplate': ('Order Id: %{customdata[0]}<br>' ... '<br>Fees: %{customdata[2]:.6f}'),
#               'legendgroup': '1',
#               'marker': {'color': '#37B13F',
#                          'line': {'color': 'rgb(38,123,44)', 'width': 1},
#                          'size': 8,
#                          'symbol': 'triangle-up'},
#               'mode': 'markers',
#               'name': 'Buy',
#               'type': 'scatter',
#               'uid': '5f3aad9b-9b1c-4ef7-a21f-0798881edacc',
#               'x': array([Timestamp('2025-01-02 00:00:00+0800', tz='UTC+08:00'),
#                           Timestamp('2025-01-03 00:00:00+0800', tz='UTC+08:00'),
#                           Timestamp('2025-01-06 00:00:00+0800', tz='UTC+08:00'),
#                           Timestamp('2025-01-07 00:00:00+0800', tz='UTC+08:00'),
#                           Timestamp('2025-09-01 00:00:00+0800', tz='UTC+08:00'),
#                           Timestamp('2025-09-02 00:00:00+0800', tz='UTC+08:00'),
#                           Timestamp('2025-09-03 00:00:00+0800', tz='UTC+08:00'),
#                           Timestamp('2025-11-25 00:00:00+0800', tz='UTC+08:00'),
#                           Timestamp('2025-11-26 00:00:00+0800', tz='UTC+08:00'),
#                           Timestamp('2025-11-27 00:00:00+0800', tz='UTC+08:00')], dtype=object),
#               'xaxis': 'x',
#               'y': {'bdata': ('io7k8h/S+T8eFmpN8475P3UCmggbnv' ... 'CC4sf6P1Frmnecovo/cvkP6bev+j8='),
#                     'dtype': 'f8'},
#               'yaxis': 'y'},
#              {'customdata': {'bdata': ('AAAAAAAAIEAAAAAAgNS+QAAAAAAAAA' ... 'AAAAAAOECPwvUoXGdyQAAAAAAAAAAA'),
#                              'dtype': 'f8',
#                              'shape': '6, 3'},
#               'hovertemplate': ('Order Id: %{customdata[0]}<br>' ... '<br>Fees: %{customdata[2]:.6f}'),
#               'legendgroup': '2',
#               'marker': {'color': '#EA4335',
#                          'line': {'color': 'rgb(181,31,18)', 'width': 1},
#                          'size': 8,
#                          'symbol': 'triangle-down'},
#               'mode': 'markers',
#               'name': 'Sell',
#               'type': 'scatter',
#               'uid': 'eb138473-753f-43f0-9bfc-8661d865f6b0',
#               'x': array([Timestamp('2025-05-12 00:00:00+0800', tz='UTC+08:00'),
#                           Timestamp('2025-05-13 00:00:00+0800', tz='UTC+08:00'),
#                           Timestamp('2025-05-14 00:00:00+0800', tz='UTC+08:00'),
#                           Timestamp('2025-10-27 00:00:00+0800', tz='UTC+08:00'),
#                           Timestamp('2025-10-28 00:00:00+0800', tz='UTC+08:00'),
#                           Timestamp('2025-10-29 00:00:00+0800', tz='UTC+08:00')], dtype=object),
#               'xaxis': 'x',
#               'y': {'bdata': 'LbKd76fG+T++wRcmUwX6Pylcj8L1KPo/4L4OnDOi+j8LRiV1Apr6P6K0N/jCZPo/', 'dtype': 'f8'},
#               'yaxis': 'y'},
#              {'customdata': {'bdata': ('AAAAAAAAJEAAAAAAAADwPwCx7n0RdE' ... 'AAAPA/AJruXdzzEEBcpy0cc3hYPw=='),
#                              'dtype': 'f8',
#                              'shape': '5, 4'},
#               'hovertemplate': ('Exit Trade Id: %{customdata[0]' ... 'r>Return: %{customdata[3]:.2%}'),
#               'legendgroup': '3',
#               'marker': {'color': '#37B13F',
#                          'line': {'color': 'rgb(38,123,44)', 'width': 1},
#                          'opacity': {'bdata': 'ZppDTWBU6D+13fdE8i3rP83MzMzMzOw/FXRXrE5c6D8AAAAAAADoPw==', 'dtype': 'f8'},
#                          'size': {'bdata': 'pgS1wjHsHUD6m32eAkYnQAAAAAAAACxAJiX+l3UaHkAAAAAAAAAcQA==', 'dtype': 'f8'},
#                          'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'Closed - Profit',
#               'type': 'scatter',
#               'uid': '6b92afc3-fcdc-47a4-bfcd-1e7bebc44aec',
#               'x': array([Timestamp('2025-05-12 00:00:00+0800', tz='UTC+08:00'),
#                           Timestamp('2025-05-13 00:00:00+0800', tz='UTC+08:00'),
#                           Timestamp('2025-05-14 00:00:00+0800', tz='UTC+08:00'),
#                           Timestamp('2025-10-27 00:00:00+0800', tz='UTC+08:00'),
#                           Timestamp('2025-10-28 00:00:00+0800', tz='UTC+08:00')], dtype=object),
#               'xaxis': 'x2',
#               'y': {'bdata': 'RD3rj6ZBZT/wNY2ymtCIP3vvJJem85E/+d2DBrsaZj9cpy0cc3hYPw==', 'dtype': 'f8'},
#               'yaxis': 'y2'},
#              {'customdata': {'bdata': 'AAAAAAAALkAAAAAAAADwPwCGv39vyAjAVflWAAj1eb8=', 'dtype': 'f8', 'shape': '1, 4'},
#               'hovertemplate': ('Exit Trade Id: %{customdata[0]' ... 'r>Return: %{customdata[3]:.2%}'),
#               'legendgroup': '4',
#               'marker': {'color': '#EA4335',
#                          'line': {'color': 'rgb(181,31,18)', 'width': 1},
#                          'opacity': {'bdata': 'hj4+Uh9z6T8=', 'dtype': 'f8'},
#                          'size': {'bdata': 'XDbgr3A6IkA=', 'dtype': 'f8'},
#                          'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'Closed - Loss',
#               'type': 'scatter',
#               'uid': '8f3931f2-d168-49ba-987c-087a36f1a265',
#               'x': array([Timestamp('2025-10-29 00:00:00+0800', tz='UTC+08:00')], dtype=object),
#               'xaxis': 'x2',
#               'y': {'bdata': 'VflWAAj1eb8=', 'dtype': 'f8'},
#               'yaxis': 'y2'},
#              {'customdata': {'bdata': 'AAAAAAAAMEAAAAAAAADwPwASC12UX0vAGdINXpSuZr8=', 'dtype': 'f8', 'shape': '1, 4'},
#               'hovertemplate': ('Exit Trade Id: %{customdata[0]' ... 'r>Return: %{customdata[3]:.2%}'),
#               'legendgroup': '5',
#               'marker': {'color': '#FFAA00',
#                          'line': {'color': 'rgb(178,118,0)', 'width': 1},
#                          'opacity': {'bdata': 'zuQ0hbVh6D8=', 'dtype': 'f8'},
#                          'size': {'bdata': 'BYy0M/g5HkA=', 'dtype': 'f8'},
#                          'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'Open',
#               'type': 'scatter',
#               'uid': '224d2861-30e4-4430-997f-b40df845d42d',
#               'x': array([Timestamp('2025-11-28 00:00:00+0800', tz='UTC+08:00')], dtype=object),
#               'xaxis': 'x2',
#               'y': {'bdata': 'GdINXpSuZr8=', 'dtype': 'f8'},
#               'yaxis': 'y2'},
#              {'legendgroup': '6',
#               'line': {'color': '#7f7f7f'},
#               'name': 'Benchmark',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': 'c65a5cc9-0651-4c3a-9509-15acf17ccfec',
#               'x': array([Timestamp('2025-01-02 00:00:00+0800', tz='UTC+08:00'),
#                           Timestamp('2025-01-03 00:00:00+0800', tz='UTC+08:00'),
#                           Timestamp('2025-01-06 00:00:00+0800', tz='UTC+08:00'), ...,
#                           Timestamp('2025-11-26 00:00:00+0800', tz='UTC+08:00'),
#                           Timestamp('2025-11-27 00:00:00+0800', tz='UTC+08:00'),
#                           Timestamp('2025-11-28 00:00:00+0800', tz='UTC+08:00')],
#                          shape=(220,), dtype=object),
#               'xaxis': 'x3',
#               'y': {'bdata': ('AAAAAAAA8D8BzgcCwKzvPzsLhjOIv+' ... 'OSMIHwP3ggs8pPifA/HY4zO76E8D8='),
#                     'dtype': 'f8'},
#               'yaxis': 'y3'},
#              {'hoverinfo': 'skip',
#               'legendgroup': '7',
#               'line': {'color': 'rgba(0, 0, 0, 0)', 'width': 0},
#               'opacity': 0,
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '7cc75f43-3fd7-4b1d-b0de-5019acd21308',
#               'x': array([Timestamp('2025-01-02 00:00:00+0800', tz='UTC+08:00'),
#                           Timestamp('2025-01-03 00:00:00+0800', tz='UTC+08:00'),
#                           Timestamp('2025-01-06 00:00:00+0800', tz='UTC+08:00'), ...,
#                           Timestamp('2025-11-26 00:00:00+0800', tz='UTC+08:00'),
#                           Timestamp('2025-11-27 00:00:00+0800', tz='UTC+08:00'),
#                           Timestamp('2025-11-28 00:00:00+0800', tz='UTC+08:00')],
#                          shape=(220,), dtype=object),
#               'xaxis': 'x3',
#               'y': {'bdata': ('AQEBAQEBAQEBAQEBAQEBAQEBAQEBAQ' ... 'EBAQEBAQEBAQEBAQEBAQEBAQEBAQ=='),
#                     'dtype': 'i1'},
#               'yaxis': 'y3'},
#              {'connectgaps': False,
#               'fill': 'tonexty',
#               'fillcolor': 'rgba(0, 128, 0, 0.3)',
#               'hoverinfo': 'skip',
#               'legendgroup': '7',
#               'line': {'color': 'rgba(0, 0, 0, 0)', 'width': 0},
#               'opacity': 0,
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': 'c8b3a2b0-bc3a-488a-9257-b42758d6991f',
#               'x': array([Timestamp('2025-01-02 00:00:00+0800', tz='UTC+08:00'),
#                           Timestamp('2025-01-03 00:00:00+0800', tz='UTC+08:00'),
#                           Timestamp('2025-01-06 00:00:00+0800', tz='UTC+08:00'), ...,
#                           Timestamp('2025-11-26 00:00:00+0800', tz='UTC+08:00'),
#                           Timestamp('2025-11-27 00:00:00+0800', tz='UTC+08:00'),
#                           Timestamp('2025-11-28 00:00:00+0800', tz='UTC+08:00')],
#                          shape=(220,), dtype=object),
#               'xaxis': 'x3',
#               'y': {'bdata': ('AAAAAAAA8D8AAAAAAADwPwAAAAAAAP' ... 'F9hAjwP6MoyW0NEPA/6RKgjbAL8D8='),
#                     'dtype': 'f8'},
#               'yaxis': 'y3'},
#              {'hoverinfo': 'skip',
#               'legendgroup': '7',
#               'line': {'color': 'rgba(0, 0, 0, 0)', 'width': 0},
#               'opacity': 0,
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': 'ed9956ab-6e84-4297-9c34-c586706f7739',
#               'x': array([Timestamp('2025-01-02 00:00:00+0800', tz='UTC+08:00'),
#                           Timestamp('2025-01-03 00:00:00+0800', tz='UTC+08:00'),
#                           Timestamp('2025-01-06 00:00:00+0800', tz='UTC+08:00'), ...,
#                           Timestamp('2025-11-26 00:00:00+0800', tz='UTC+08:00'),
#                           Timestamp('2025-11-27 00:00:00+0800', tz='UTC+08:00'),
#                           Timestamp('2025-11-28 00:00:00+0800', tz='UTC+08:00')],
#                          shape=(220,), dtype=object),
#               'xaxis': 'x3',
#               'y': {'bdata': ('AQEBAQEBAQEBAQEBAQEBAQEBAQEBAQ' ... 'EBAQEBAQEBAQEBAQEBAQEBAQEBAQ=='),
#                     'dtype': 'i1'},
#               'yaxis': 'y3'},
#              {'connectgaps': False,
#               'fill': 'tonexty',
#               'fillcolor': 'rgba(255, 0, 0, 0.3)',
#               'hoverinfo': 'skip',
#               'legendgroup': '7',
#               'line': {'color': 'rgba(0, 0, 0, 0)', 'width': 0},
#               'opacity': 0,
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '2480944e-80d9-40f0-9f57-2030fda9d7ec',
#               'x': array([Timestamp('2025-01-02 00:00:00+0800', tz='UTC+08:00'),
#                           Timestamp('2025-01-03 00:00:00+0800', tz='UTC+08:00'),
#                           Timestamp('2025-01-06 00:00:00+0800', tz='UTC+08:00'), ...,
#                           Timestamp('2025-11-26 00:00:00+0800', tz='UTC+08:00'),
#                           Timestamp('2025-11-27 00:00:00+0800', tz='UTC+08:00'),
#                           Timestamp('2025-11-28 00:00:00+0800', tz='UTC+08:00')],
#                          shape=(220,), dtype=object),
#               'xaxis': 'x3',
#               'y': {'bdata': ('AAAAAAAA8D8FWRcDYNbvP466Zorq5e' ... 'AAAADwPwAAAAAAAPA/AAAAAAAA8D8='),
#                     'dtype': 'f8'},
#               'yaxis': 'y3'},
#              {'legendgroup': '8',
#               'line': {'color': '#9467bd'},
#               'name': 'Value',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '254a0976-8c76-4920-9705-4151a20775a5',
#               'x': array([Timestamp('2025-01-02 00:00:00+0800', tz='UTC+08:00'),
#                           Timestamp('2025-01-03 00:00:00+0800', tz='UTC+08:00'),
#                           Timestamp('2025-01-06 00:00:00+0800', tz='UTC+08:00'), ...,
#                           Timestamp('2025-11-26 00:00:00+0800', tz='UTC+08:00'),
#                           Timestamp('2025-11-27 00:00:00+0800', tz='UTC+08:00'),
#                           Timestamp('2025-11-28 00:00:00+0800', tz='UTC+08:00')],
#                          shape=(220,), dtype=object),
#               'xaxis': 'x3',
#               'y': {'bdata': ('AAAAAAAA8D8FWRcDYNbvP466Zorq5e' ... 'F9hAjwP6MoyW0NEPA/6RKgjbAL8D8='),
#                     'dtype': 'f8'},
#               'yaxis': 'y3'},
#              {'hoverinfo': 'skip',
#               'legendgroup': '7',
#               'line': {'color': 'rgba(0, 0, 0, 0)', 'width': 0},
#               'opacity': 0.0,
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': 'c4563e17-6a6a-443a-b3d3-4fd580704dc2',
#               'x': array([Timestamp('2025-01-02 00:00:00+0800', tz='UTC+08:00'),
#                           Timestamp('2025-01-03 00:00:00+0800', tz='UTC+08:00'),
#                           Timestamp('2025-01-06 00:00:00+0800', tz='UTC+08:00'), ...,
#                           Timestamp('2025-11-26 00:00:00+0800', tz='UTC+08:00'),
#                           Timestamp('2025-11-27 00:00:00+0800', tz='UTC+08:00'),
#                           Timestamp('2025-11-28 00:00:00+0800', tz='UTC+08:00')],
#                          shape=(220,), dtype=object),
#               'xaxis': 'x3',
#               'y': {'bdata': ('AQEBAQEBAQEBAQEBAQEBAQEBAQEBAQ' ... 'EBAQEBAQEBAQEBAQEBAQEBAQEBAQ=='),
#                     'dtype': 'i1'},
#               'yaxis': 'y3'}],
#     'layout': {'annotations': [{'font': {'size': 16},
#                                 'showarrow': False,
#                                 'text': 'Orders',
#                                 'x': 0.5,
#                                 'xanchor': 'center',
#                                 'xref': 'paper',
#                                 'y': 1.0,
#                                 'yanchor': 'bottom',
#                                 'yref': 'paper'},
#                                {'font': {'size': 16},
#                                 'showarrow': False,
#                                 'text': 'Trade PnL',
#                                 'x': 0.5,
#                                 'xanchor': 'center',
#                                 'xref': 'paper',
#                                 'y': 0.6527777777777777,
#                                 'yanchor': 'bottom',
#                                 'yref': 'paper'},
#                                {'font': {'size': 16},
#                                 'showarrow': False,
#                                 'text': 'Cumulative Returns',
#                                 'x': 0.5,
#                                 'xanchor': 'center',
#                                 'xref': 'paper',
#                                 'y': 0.3055555555555555,
#                                 'yanchor': 'bottom',
#                                 'yref': 'paper'}],
#                'height': 960,
#                'legend': {'orientation': 'h',
#                           'traceorder': 'normal',
#                           'x': 1,
#                           'xanchor': 'right',
#                           'y': 1.0416666666666667,
#                           'yanchor': 'bottom'},
#                'margin': {'b': 30, 'l': 30, 'r': 30, 't': 30},
#                'shapes': [{'line': {'color': 'gray', 'dash': 'dash'},
#                            'type': 'line',
#                            'x0': 0.0,
#                            'x1': 1.0,
#                            'xref': 'paper',
#                            'y0': 0,
#                            'y1': 0,
#                            'yref': 'y2'},
#                           {'line': {'color': 'gray', 'dash': 'dash'},
#                            'type': 'line',
#                            'x0': 0.0,
#                            'x1': 1.0,
#                            'xref': 'paper',
#                            'y0': 1,
#                            'y1': 1,
#                            'yref': 'y3'}],
#                'showlegend': True,
#                'template': '...',
#                'width': 750,
#                'xaxis': {'anchor': 'y', 'domain': [0.0, 1.0], 'matches': 'x3', 'showticklabels': False},
#                'xaxis2': {'anchor': 'y2', 'domain': [0.0, 1.0], 'matches': 'x3', 'showticklabels': False},
#                'xaxis3': {'anchor': 'y3', 'domain': [0.0, 1.0], 'title': {'text': 'Index'}},
#                'yaxis': {'anchor': 'x', 'domain': [0.6944444444444444, 1.0], 'title': {'text': 'Price'}},
#                'yaxis2': {'anchor': 'x2',
#                           'domain': [0.3472222222222222, 0.6527777777777777],
#                           'tickformat': '.2%',
#                           'title': {'text': 'Trade PnL'}},
#                'yaxis3': {'anchor': 'x3', 'domain': [0.0, 0.3055555555555555], 'title': {'text': 'Cumulative returns'}}}
# })

# %% [markdown]
# ## Hyperparameter Optimization

# %%
strategy = DualReallocationStrategy(
    prices = price_data,
    threshold= np.arange(0.3, 2.0, 0.01),
    adjust_factor= np.arange(0.1, 1.1, 0.1),
    default_weights = 0.5,
    up_weights = np.arange(0.1, 0.5, 0.1),
    down_weights= np.arange(0.6, 1.0, 0.1),
    tolerance=0.01,
    hw_params_list = opt_res
)

# %%
bt = RBT(
    strategy=strategy,
    start_date=val.index[0],
    end_date=val.index[-1],
    initial_cash=100_000,
    fees=0.00075,
    trade_delay=0
)

bt.run()
# Out:
# 100%|██████████| 27200/27200 [05:27<00:00, 82.99it/s]

# %%
bt.stats() # selected=1
# Out:
#                                                                                        benchmark_return  \
# param_group threshold adjust_factor default_weights up_weights down_weights tolerance
# 0           0.30      0.1           0.5             0.1        0.6          0.01               0.116117
# 1           0.30      0.1           0.5             0.1        0.7          0.01               0.116117
# 2           0.30      0.1           0.5             0.1        0.8          0.01               0.116117
# 3           0.30      0.1           0.5             0.1        0.9          0.01               0.116117
# 4           0.30      0.1           0.5             0.2        0.6          0.01               0.116117
# ...                                                                                                 ...
# 27195       1.99      1.0           0.5             0.3        0.9          0.01               0.116117
# 27196       1.99      1.0           0.5             0.4        0.6          0.01               0.116117
# 27197       1.99      1.0           0.5             0.4        0.7          0.01               0.116117
# 27198       1.99      1.0           0.5             0.4        0.8          0.01               0.116117
# 27199       1.99      1.0           0.5             0.4        0.9          0.01               0.116117
#
#                                                                                        total_return  \
# param_group threshold adjust_factor default_weights up_weights down_weights tolerance
# 0           0.30      0.1           0.5             0.1        0.6          0.01           0.121647
# 1           0.30      0.1           0.5             0.1        0.7          0.01           0.106384
# 2           0.30      0.1           0.5             0.1        0.8          0.01           0.091226
# 3           0.30      0.1           0.5             0.1        0.9          0.01           0.076176
# 4           0.30      0.1           0.5             0.2        0.6          0.01           0.115028
# ...                                                                                             ...
# 27195       1.99      1.0           0.5             0.3        0.9          0.01           0.115374
# 27196       1.99      1.0           0.5             0.4        0.6          0.01           0.115374
# 27197       1.99      1.0           0.5             0.4        0.7          0.01           0.115374
# 27198       1.99      1.0           0.5             0.4        0.8          0.01           0.115374
# 27199       1.99      1.0           0.5             0.4        0.9          0.01           0.115374
#
#                                                                                        sharpe_ratio  \
# param_group threshold adjust_factor default_weights up_weights down_weights tolerance
# 0           0.30      0.1           0.5             0.1        0.6          0.01           2.344893
# 1           0.30      0.1           0.5             0.1        0.7          0.01           2.122449
# 2           0.30      0.1           0.5             0.1        0.8          0.01           1.856769
# 3           0.30      0.1           0.5             0.1        0.9          0.01           1.559258
# 4           0.30      0.1           0.5             0.2        0.6          0.01           2.264215
# ...                                                                                             ...
# 27195       1.99      1.0           0.5             0.3        0.9          0.01           2.209050
# 27196       1.99      1.0           0.5             0.4        0.6          0.01           2.209050
# 27197       1.99      1.0           0.5             0.4        0.7          0.01           2.209050
# 27198       1.99      1.0           0.5             0.4        0.8          0.01           2.209050
# 27199       1.99      1.0           0.5             0.4        0.9          0.01           2.209050
#
#                                                                                        max_drawdown
# param_group threshold adjust_factor default_weights up_weights down_weights tolerance
# 0           0.30      0.1           0.5             0.1        0.6          0.01          -0.050749
# 1           0.30      0.1           0.5             0.1        0.7          0.01          -0.043014
# 2           0.30      0.1           0.5             0.1        0.8          0.01          -0.044434
# 3           0.30      0.1           0.5             0.1        0.9          0.01          -0.045853
# 4           0.30      0.1           0.5             0.2        0.6          0.01          -0.047347
# ...                                                                                             ...
# 27195       1.99      1.0           0.5             0.3        0.9          0.01          -0.053519
# 27196       1.99      1.0           0.5             0.4        0.6          0.01          -0.053519
# 27197       1.99      1.0           0.5             0.4        0.7          0.01          -0.053519
# 27198       1.99      1.0           0.5             0.4        0.8          0.01          -0.053519
# 27199       1.99      1.0           0.5             0.4        0.9          0.01          -0.053519
#
# [27200 rows x 4 columns]

# %%
bt.plot(index_levels=['threshold', 'adjust_factor'], column_levels=['up_weights', 'down_weights'])

# %%
# Map top indices to their parameter sets without using an unhashable Index as a dict key
best_params = bt.get_best_param(metric='total_return', top_n=5)
best_params
# Out:
#    param_group  threshold  adjust_factor  default_weights  up_weights  \
# 0        10065       0.92            1.0              0.5         0.1
# 1        10064       0.92            1.0              0.5         0.1
# 2        10066       0.92            1.0              0.5         0.1
# 3        10067       0.92            1.0              0.5         0.1
# 4        10048       0.92            0.9              0.5         0.1
#
#    down_weights  tolerance  total_return
# 0           0.7       0.01      0.247490
# 1           0.6       0.01      0.247439
# 2           0.8       0.01      0.247410
# 3           0.9       0.01      0.247197
# 4           0.6       0.01      0.246761

# %%
best_params= bt.get_weighted_best_params(
    metric_weight = {
        'total_return': 0.45,
        'sharpe_ratio': 0.45,
        'max_drawdown': 0.1
    },
    top_n=10
)

# %%
best_params
# Out:
#    param_group  threshold  adjust_factor  default_weights  up_weights  \
# 0         8496       0.83            0.2              0.5         0.1
# 1         9296       0.88            0.2              0.5         0.1
# 2         9616       0.90            0.2              0.5         0.1
# 3         7056       0.74            0.2              0.5         0.1
# 4         7856       0.79            0.2              0.5         0.1
# 5         7536       0.77            0.2              0.5         0.1
# 6         8336       0.82            0.2              0.5         0.1
# 7         9136       0.87            0.2              0.5         0.1
# 8         8016       0.80            0.2              0.5         0.1
# 9         7216       0.75            0.2              0.5         0.1
#
#    down_weights  tolerance  weighted_score  total_return  sharpe_ratio  \
# 0           0.6       0.01        0.950064        0.1652      2.986103
# 1           0.6       0.01        0.950064        0.1652      2.986103
# 2           0.6       0.01        0.950064        0.1652      2.986103
# 3           0.6       0.01        0.950064        0.1652      2.986103
# 4           0.6       0.01        0.950064        0.1652      2.986103
# 5           0.6       0.01        0.950064        0.1652      2.986103
# 6           0.6       0.01        0.950064        0.1652      2.986103
# 7           0.6       0.01        0.950064        0.1652      2.986103
# 8           0.6       0.01        0.950064        0.1652      2.986103
# 9           0.6       0.01        0.950064        0.1652      2.986103
#
#    max_drawdown
# 0     -0.053391
# 1     -0.053391
# 2     -0.053391
# 3     -0.053391
# 4     -0.053391
# 5     -0.053391
# 6     -0.053391
# 7     -0.053391
# 8     -0.053391
# 9     -0.053391

# %% [markdown]
# ## Best Param Strategy

# %%
best_strategy = DualReallocationStrategy(
    prices = price_data,
    threshold = best_params['threshold'][0],
    adjust_factor = best_params['adjust_factor'][0],
    default_weights = 0.,
    up_weights = best_params['up_weights'][0],
    down_weights = best_params['down_weights'][0],
    tolerance=0.01,
    hw_params_list = opt_res
)

# %%
best_bt = RBT(
    strategy=best_strategy,
    start_date=test.index[0],
    # end_date="2025-07-02",
    initial_cash=20_000,
    fees=0.0,
    trade_delay=0
)

best_bt.run()
# Out:
# 100%|██████████| 1/1 [00:00<00:00, 19.51it/s]

# %%
best_strategy.hw_signals
# Out:
#                              007467    004253
# date
# 2024-07-17 00:00:00+08:00 -0.556667  0.946667
# 2024-07-18 00:00:00+08:00 -0.384359  0.920133
# 2024-07-19 00:00:00+08:00 -0.607321 -0.670549
# 2024-07-22 00:00:00+08:00 -0.813953 -0.239203
# 2024-07-23 00:00:00+08:00 -0.850498 -0.677741
# ...                             ...       ...
# 2025-10-23 00:00:00+08:00  0.816733 -0.399734
# 2025-10-24 00:00:00+08:00  0.493369 -0.864721
# 2025-10-27 00:00:00+08:00  0.506631 -0.949602
# 2025-10-28 00:00:00+08:00  0.486093 -1.000000
# 2025-10-29 00:00:00+08:00  0.115232 -0.994702
#
# [311 rows x 2 columns]

# %%
best_bt.pf.orders.records_readable
# Out:
#     Order Id                                       Column  \
# 0          0  (0, 0.92, 0.8, 0.5, 0.1, 0.6, 0.01, 004253)
#
# Max Gross Exposure [%]                            100.0
# Total Fees Paid                                     0.0
# Max Drawdown [%]                               4.747755
# Max Drawdown Duration                  27 days 00:00:00
# Total Trades                                         53
# Total Closed Trades                                  51
# Total Open Trades                                     2
# Open Trade PnL                              1105.071704
# Win Rate [%]                                  94.117647
# Best Trade [%]                                10.753211
# Worst Trade [%]                               -0.871849
# Avg Winning Trade [%]                          3.497684
# Avg Losing Trade [%]                          -0.496994
# Avg Winning Trade Duration             44 days 16:30:00
# Avg Losing Trade Duration              35 days 00:00:00
# Profit Factor                                 94.177275
# Expectancy                                    14.419296
# Sharpe Ratio                                   1.975918
# Calmar Ratio                                   5.007955
# Omega Ratio                                    1.407831
# Sortino Ratio                                  3.007513
# dtype: object

# %%
best_bt.plot()

# %%
best_bt.pf.orders.records_readable
# Out:
#      Order Id                                       Column  \
# 0           0  (0, 0.83, 0.2, 0.0, 0.1, 0.6, 0.01, 004253)
# 1           1  (0, 0.83, 0.2, 0.0, 0.1, 0.6, 0.01, 004253)
# 2           2  (0, 0.83, 0.2, 0.0, 0.1, 0.6, 0.01, 007467)
# 3           3  (0, 0.83, 0.2, 0.0, 0.1, 0.6, 0.01, 004253)
# 4           4  (0, 0.83, 0.2, 0.0, 0.1, 0.6, 0.01, 007467)
# ..        ...                                          ...
# 98         98  (0, 0.83, 0.2, 0.0, 0.1, 0.6, 0.01, 004253)
# 99         99  (0, 0.83, 0.2, 0.0, 0.1, 0.6, 0.01, 007467)
# 100       100  (0, 0.83, 0.2, 0.0, 0.1, 0.6, 0.01, 004253)
# 101       101  (0, 0.83, 0.2, 0.0, 0.1, 0.6, 0.01, 007467)
# 102       102  (0, 0.83, 0.2, 0.0, 0.1, 0.6, 0.01, 004253)
#
#                     Timestamp     Size   Price  Fees  Side
# 0   2025-05-28 00:00:00+08:00  7295.80  2.7413   0.0   Buy
# 1   2025-05-29 00:00:00+08:00   145.90  2.7174   0.0  Sell
# 2   2025-05-29 00:00:00+08:00   242.51  1.6349   0.0   Buy
# 3   2025-05-30 00:00:00+08:00   117.36  2.7379   0.0  Sell
# 4   2025-05-30 00:00:00+08:00   195.94  1.6399   0.0   Buy
# ..                        ...      ...     ...   ...   ...
# 98  2025-10-27 00:00:00+08:00   435.49  3.2970   0.0   Buy
# 99  2025-10-28 00:00:00+08:00   766.79  1.6626   0.0  Sell
# 100 2025-10-28 00:00:00+08:00   401.36  3.1764   0.0   Buy
# 101 2025-10-29 00:00:00+08:00   488.22  1.6492   0.0  Sell
# 102 2025-10-29 00:00:00+08:00   251.47  3.2018   0.0   Buy
#
# [103 rows x 7 columns]

# %%
delta_hdp = - best_strategy.hw_signals.iloc[:, 0] + best_strategy.hw_signals.iloc[:, 1]

# %%
best_strategy.hw_signals
# Out:
#                              007467    004253
# date
# 2025-05-28 00:00:00+08:00  0.335227 -0.446023
# 2025-05-29 00:00:00+08:00  0.232955 -0.877841
# 2025-05-30 00:00:00+08:00  0.293617 -0.273759
# 2025-06-03 00:00:00+08:00  0.690780  0.571631
# 2025-06-04 00:00:00+08:00  0.742210  0.399433
# ...                             ...       ...
# 2025-10-23 00:00:00+08:00  0.819389 -0.776892
# 2025-10-24 00:00:00+08:00  0.498674 -0.928382
# 2025-10-27 00:00:00+08:00  0.509284 -0.954907
# 2025-10-28 00:00:00+08:00  0.480795 -1.000000
# 2025-10-29 00:00:00+08:00 -0.027815 -0.994702
#
# [104 rows x 2 columns]

# %%
delta_hdp
# Out:
# date
# 2025-05-28 00:00:00+08:00   -0.781250
# 2025-05-29 00:00:00+08:00   -1.110795
# 2025-05-30 00:00:00+08:00   -0.567376
# 2025-06-03 00:00:00+08:00   -0.119149
# 2025-06-04 00:00:00+08:00   -0.342776
#                                ...
# 2025-10-23 00:00:00+08:00   -1.596282
# 2025-10-24 00:00:00+08:00   -1.427056
# 2025-10-27 00:00:00+08:00   -1.464191
# 2025-10-28 00:00:00+08:00   -1.480795
# 2025-10-29 00:00:00+08:00   -0.966887
# Length: 104, dtype: float64
